# %%
f = open("C:\\Users\\91418\\Desktop\\Demo\\Data\\test_data.txt")
f2 = open("C:\\Users\\91418\\Desktop\\Demo\\Data\\data_record.txt")
list1 = f.readlines()
list2 = f2.readlines()

# %%
import re
number = []
number2 = []
for list in list1:
    number.append(re.findall("-?\d+\.?\d*",list)) 
for list in list2:
    number2.append(re.findall("-?\d+\.?\d*",list))

# %%
number[400]
# Out:
# ['399', '13985.895123324102', '6992.947561662051', '1', '0']

# %%
del(number[0])

# %%
import pandas as pd
df = pd.DataFrame(number)
df2 = pd.DataFrame(number2)
# df_t = pd.read_csv("C:\\Users\\91418\\Desktop\\Demo\\ADS_Write\\time_record.csv")

# %%
import numpy as np
x= np.array(range(0,len(df)))
x2 = np.array(range(0,len(df2)))
# x2 = x2 + np.array(df_t['2'])
y = pd.to_numeric(df[1])
y2 = pd.to_numeric(df2[1][0:len(x)])

# %%
end=4000
import matplotlib.pyplot as plt

fig =plt.figure(figsize=(10,8),dpi = 500)
fig1=fig.add_subplot(2,1,1)
fig1.plot(x[0:end],y[0:end])
fig1.plot(x2[0:end],y2[0:end])

fig2 = fig.add_subplot(2,1,2)
fig2.plot(y2[1:end+1]-y[0:end])
